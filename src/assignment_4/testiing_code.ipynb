# %%
from pathlib import Path

# %%
import pandas as pd

# %%
SRC = Path('.').parent.resolve()
BLD = SRC.joinpath("..", "..", "bld").resolve()

# %%
df = pd.read_csv(BLD/"python"/"data"/"merged_chs_nlsy_data.csv")

# %%
df
# Out:
#        Unnamed: 0  childid  year  momid  age      bpiA      bpiB      bpiC  \
# 0               3      201  1998      2    5  0.954977  0.252469  0.761378
# 1               4      201  2000      2    7       NaN -0.305677  1.376603
# 2               5      201  2002      2    9 -0.393110  1.137765  1.375050
# 3               6      201  2004      2   11  0.890382  1.162996  1.386174
# 4               7      201  2006      2   13       NaN       NaN       NaN
# ...           ...      ...   ...    ...  ...       ...       ...       ...
# 11030       17651  1255601  1983  12556    5       NaN       NaN       NaN
# 11031       17652  1255601  1985  12556    7 -0.428740 -1.727758 -1.045441
# 11032       17653  1255601  1987  12556    9  0.249955 -2.236943 -1.621489
# 11033       17654  1255601  1989  12556   11       NaN       NaN       NaN
# 11034       17655  1255601  1991  12556   13       NaN       NaN       NaN
#
#            bpiD      bpiE  ...  antisocial  anxiety  headstrong hyperactive  \
# 0     -0.103273  0.547242  ...         NaN      NaN         NaN         NaN
# 1     -0.060863 -0.735066  ...         NaN      NaN         NaN         NaN
# 2      1.145124  0.591180  ...         NaN      NaN         NaN         NaN
# 3      1.097578  0.597735  ...         NaN      NaN         NaN         NaN
# 4           NaN       NaN  ...    0.166667     0.00         0.6         0.2
# ...         ...       ...  ...         ...      ...         ...         ...
# 11030       NaN       NaN  ...    0.666667     0.40         0.8         1.0
# 11031 -0.696726 -0.735066  ...    0.333333     0.20         0.4         0.2
# 11032  0.527780  0.591180  ...    0.833333     0.75         0.6         0.6
# 11033       NaN       NaN  ...         NaN      NaN         NaN         NaN
# 11034       NaN       NaN  ...         NaN      NaN         NaN         NaN
#
#       dependence      peer additional_gethim additional_hangout  \
# 0            NaN       NaN               NaN                NaN
# 1            NaN       NaN               NaN                NaN
# 2            NaN       NaN               NaN                NaN
# 3            NaN       NaN               NaN                NaN
# 4            NaN  0.333333               NaN                NaN
# ...          ...       ...               ...                ...
# 11030        NaN  1.000000          not true     sometimes true
# 11031        NaN  0.000000          not true           not true
# 11032        NaN  0.333333          not true           not true
# 11033        NaN       NaN               NaN                NaN
# 11034        NaN       NaN               NaN                NaN
#
#       additional_secretive additional_worries
# 0                      NaN                NaN
# 1                      NaN                NaN
# 2                      NaN                NaN
# 3                      NaN                NaN
# 4                      NaN                NaN
# ...                    ...                ...
# 11030       sometimes true           not true
# 11031             not true           not true
# 11032             not true           not true
# 11033                  NaN                NaN
# 11034                  NaN                NaN
#
# [11035 rows x 51 columns]

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
df['antisocial']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4        0.166667
#            ...
# 11030    0.666667
# 11031    0.333333
# 11032    0.833333
# 11033         NaN
# 11034         NaN
# Name: antisocial, Length: 11035, dtype: float64

# %%
df['bpiA']
# Out:
# 0        0.954977
# 1             NaN
# 2       -0.393110
# 3        0.890382
# 4             NaN
#            ...
# 11030         NaN
# 11031   -0.428740
# 11032    0.249955
# 11033         NaN
# 11034         NaN
# Name: bpiA, Length: 11035, dtype: float64

# %%
px.scatter(df, x='antisocial', y='bpiA', facet_col="age", trendline="ols")
